# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sqlalchemy import create_engine
# import sqlalchemy

# %%
engine = create_engine('postgresql://postgres:Maneco707@localhost:5432/SQL HW.')
connection = engine.connect()

# %%
pd.read_sql('Select * from Employees',connection)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
pd.read_sql('Select * from Salaries where salary = 60117',connection)
# Out:
#    emp_no  salary   from_date     to_date
# 0   10001   60117  1986-06-26  1987-06-26
# 1   78958   60117  1990-02-06  1991-02-06
# 2  214810   60117  1998-01-31  1999-01-31
# 3  248678   60117  1991-09-23  1992-09-22
# 4  257334   60117  1994-10-16  1995-10-16
# 5  435829   60117  1989-06-23  1990-06-23
# 6  496998   60117  1987-12-15  1988-07-11

# %%
Salaries= pd.read_sql('Select * from Salaries',connection)
Salaries
# Out:
#         emp_no  salary   from_date     to_date
# 0        10001   60117  1986-06-26  1987-06-26
# 1        10002   65828  1996-08-03  1997-08-03
# 2        10003   40006  1995-12-03  1996-12-02
# 3        10004   40054  1986-12-01  1987-12-01
# 4        10005   78228  1989-09-12  1990-09-12
# ...        ...     ...         ...         ...
# 300019  499995   40000  1997-06-02  1998-06-02
# 300020  499996   58058  1996-05-13  1997-05-13
# 300021  499997   49597  1987-08-30  1988-08-29
# 300022  499998   40000  1993-12-27  1994-12-27
# 300023  499999   63707  1997-11-30  1998-11-30
#
# [300024 rows x 4 columns]

# %%
bin_edge = (40000, 50000,60000,70000,80000,90000,100000,110000,120000,130000)

# %%
plt.hist(Salaries['salary'],bins=bin_edge)
plt.xlabel('salaries range')
plt.ylabel('Frequency salaries')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Salaries2=pd.read_sql("Select t.title,round(avg(s.salary),2) FROM Titles t Join Salaries s ON (t.emp_no = s.emp_no) group by title order by title asc", connection)
Salaries2
# Out:
#                 title     round
# 0  Assistant Engineer  48493.20
# 1            Engineer  48539.78
# 2             Manager  51531.04
# 3     Senior Engineer  48506.75
# 4        Senior Staff  58503.29
# 5               Staff  58465.27
# 6    Technique Leader  48580.51

# %%
Salaries3 = Salaries2.rename(columns={"title": "Title",
                                                "round": "Average Salary"})
Salaries3
# Out:
#                 Title  Average Salary
# 0  Assistant Engineer        48493.20
# 1            Engineer        48539.78
# 2             Manager        51531.04
# 3     Senior Engineer        48506.75
# 4        Senior Staff        58503.29
# 5               Staff        58465.27
# 6    Technique Leader        48580.51

# %%
#Create a bar chart of average salary by title
# Set x axis and tick locations
x_axis = np.arange(len(Salaries3['Title']))
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(6,4))
plt.bar(x_axis,Salaries3["Average Salary"], color = "r", width = .5)
plt.xticks(tick_locations,Salaries3['Title'].values, rotation="vertical")
plt.title("Avg Salary by Title")
plt.xlabel("Titles")
plt.ylabel("Average Salary")
# Set x and y limits
plt.xlim(-0.75, len(x_axis)-.25)
plt.ylim(0, max(Salaries3["Average Salary"])+10)
plt.show()
